# %%
import llama_index
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

# %%
import os
os.environ["OPENAI_API_KEY"] = "YOUR_API_KEY_HERE"

# %%
documents = SimpleDirectoryReader(input_files=["paul_graham_essay.txt"]).load_data()
index = VectorStoreIndex.from_documents(documents)

query_engine = index.as_query_engine()
response = query_engine.query("작가의 청소년 시절은 어떠했는지 설명해 줘.")
print(response)
# Out:
# 2025-12-01 18:11:15,825 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-01 18:11:16,771 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-01 18:11:18,645 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The author's teenage years were marked by early experiences with programming on the IBM 1401 in 9th grade, using Fortran on punch cards. Despite feeling puzzled by the limitations of the system, the author's interest in programming grew when microcomputers became available, leading to the purchase of a TRS-80 in 1980. Initially planning to study philosophy in college, the author eventually switched to AI due to influences like Heinlein's novel featuring an intelligent computer and a PBS documentary showcasing SHRDLU.

# %%
response = query_engine.query("앞으로의 계획은 뭐야?")
print(f"앞으로의 계획은 뭐야?:\n{response}")
# Out:
# 2025-12-01 18:05:23,991 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-01 18:05:24,827 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 앞으로의 계획은 뭐야?:
# 앞으로의 계획은 더 많은 에세이를 쓰고, Lisp에 대해 더 연구하는 것이다.

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
documents = SimpleDirectoryReader(input_files=["인문학의 새로운 역할에 대한 고찰.pdf"]).load_data()
index = VectorStoreIndex.from_documents(documents)
# Out:
# 2025-12-01 18:05:50,326 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-01 18:05:51,578 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
response = query_engine.query("어떤 내용이 담겨있는지 초등학생도 이해할 수 있도록 자세히 풀어서 이야기 하세요.")
print(response)
# Out:
# 2025-12-01 18:05:54,467 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-12-01 18:05:56,519 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 내용에는 젊은 시절의 경험과 학업에 대한 이야기가 담겨 있습니다. 젊은 시절에 글쓰기와 프로그래밍에 관심을 갖게 되었고, 컴퓨터와의 첫 만남, 대학 시절의 전공 변경, 그리고 예술 학교에서의 경험 등이 담겨 있습니다. 저자는 프로그래밍을 좋아했지만 대학에서 철학을 전공하려고 했으나 실제로는 인공지능에 매료되어 전공을 변경했습니다. 또한 예술 학교에서의 경험도 이야기하고 있습니다. 저자는 작은 방에서 밤에 작은 그림을 그리면서 예술에 대한 열정을 이어갔습니다.
